# %% [markdown]
# <a href="https://colab.research.google.com/github/anjanaanju18/AI-Based-Heart-Attack-Predicting-System/blob/main/Heart%20Attack%20Predicting%20Model/HEART_ATTACK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # problem statement
#
# With HadHeartAttack as the prediction variable, the task would involve using other features in the dataset to predict whether a patient has experienced a heart attack. This could be approached as a binary classification problem, where the model learns patterns from the other variables to predict the likelihood of HadHeartAttack (0 for no, 1 for yes).
#
#
# Heart disease is one of the leading causes of mortality worldwide, with heart attacks being a primary manifestation. Early detection and intervention can significantly reduce the risk and improve patient outcomes. In this project, we aim to develop a predictive model that leverages patient demographic, health, and lifestyle information to determine the likelihood of a heart attack occurrence. By analyzing this data, healthcare providers may gain insights into high-risk patients, enabling proactive measures and better allocation of medical resources.
#
# The objective is to predict whether a patient has had a heart attack (binary outcome: HadHeartAttack) based on a range of features, including medical history, lifestyle habits, and demographic details. This model could serve as an assistive tool in clinical decision-making and help in implementing preventive healthcare strategies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Patients Data ( Used for Heart Disease Prediction ) (1) (1).csv")
df.head()
# Out:
#    tientID    State     Sex GeneralHealth   AgeCategory  HeightInMeters  \
# 0         1  Alabama  Female          Fair  Age 75 to 79            1.63
# 1         2  Alabama  Female     Very good  Age 65 to 69            1.60
# 2         3  Alabama    Male     Excellent  Age 60 to 64            1.78
# 3         4  Alabama    Male     Very good  Age 70 to 74            1.78
# 4         5  Alabama  Female          Good  Age 50 to 54            1.68
#
#    WeightInKilograms        BMI  HadHeartAttack  HadAngina  ...  \
# 0          84.820000  32.099998               0          1  ...
# 1          71.669998  27.990000               0          0  ...
# 2          71.209999  22.530001               0          0  ...
# 3          95.250000  30.129999               0          0  ...
# 4          78.019997  27.760000               0          0  ...
#
#                              ECigaretteUsage  ChestScan  \
# 0  Never used e-cigarettes in my entire life          1
# ...

# %%
df.tail()
# Out:
#         tientID        State     Sex GeneralHealth   AgeCategory  \
# 237625    237626  Puerto Rico  Female          Good  Age 60 to 64
# 237626    237627  Puerto Rico  Female          Good  Age 55 to 59
# 237627    237628  Puerto Rico    Male          Fair  Age 45 to 49
# 237628    237629  Puerto Rico  Female     Very good  Age 25 to 29
# 237629    237630  Puerto Rico  Female          Good  Age 30 to 34
#
#         HeightInMeters  WeightInKilograms        BMI  HadHeartAttack  \
# 237625            1.57          90.720001  36.580002               0
# 237626            1.70          72.570000  25.059999               0
# 237627            1.75          70.309998  22.889999               1
# 237628            1.57          46.720001  18.840000               0
# 237629            1.60          83.010002  32.419998               0
#
#         HadAngina  ...                            ECigaretteUsage  ChestScan  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237630 entries, 0 to 237629
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   tientID                   237630 non-null  int64
#  1   State                      237630 non-null  object
#  2   Sex                        237630 non-null  object
#  3   GeneralHealth              237630 non-null  object
#  4   AgeCategory                237630 non-null  object
#  5   HeightInMeters             237630 non-null  float64
#  6   WeightInKilograms          237630 non-null  float64
#  7   BMI                        237630 non-null  float64
#  8   HadHeartAttack             237630 non-null  int64
#  9   HadAngina                  237630 non-null  int64
#  10  HadStroke                  237630 non-null  int64
#  11  HadAsthma                  237630 non-null  int64
#  12  HadSkinCancer              237630 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# tientID                     0
# State                        0
# Sex                          0
# GeneralHealth                0
# AgeCategory                  0
# HeightInMeters               0
# WeightInKilograms            0
# BMI                          0
# HadHeartAttack               0
# HadAngina                    0
# HadStroke                    0
# HadAsthma                    0
# HadSkinCancer                0
# HadCOPD                      0
# HadDepressiveDisorder        0
# HadKidneyDisease             0
# HadArthritis                 0
# HadDiabetes                  0
# DeafOrHardOfHearing          0
# BlindOrVisionDifficulty      0
# DifficultyConcentrating      0
# DifficultyWalking            0
# DifficultyDressingBathing    0
# DifficultyErrands            0
# SmokerStatus                 0
# ECigaretteUsage              0
# ChestScan                    0
# RaceEthnicityCategory        0
# AlcoholDrinkers              0
# HIVTesting                   0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (237630, 35)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (237630, 35)

# %%
plt.hist(df['HadHeartAttack'])
plt.show()

# %%
sns.histplot(df['BMI'],kde=True)
plt.show()

# %%
sns.countplot(data=df ,x='GeneralHealth', hue='ECigaretteUsage')
plt.show()

# %%
df.head()
# Out:
#    tientID    State     Sex GeneralHealth   AgeCategory  HeightInMeters  \
# 0         1  Alabama  Female          Fair  Age 75 to 79            1.63
# 1         2  Alabama  Female     Very good  Age 65 to 69            1.60
# 2         3  Alabama    Male     Excellent  Age 60 to 64            1.78
# 3         4  Alabama    Male     Very good  Age 70 to 74            1.78
# 4         5  Alabama  Female          Good  Age 50 to 54            1.68
#
#    WeightInKilograms        BMI  HadHeartAttack  HadAngina  ...  \
# 0          84.820000  32.099998               0          1  ...
# 1          71.669998  27.990000               0          0  ...
# 2          71.209999  22.530001               0          0  ...
# 3          95.250000  30.129999               0          0  ...
# 4          78.019997  27.760000               0          0  ...
#
#                              ECigaretteUsage  ChestScan  \
# 0  Never used e-cigarettes in my entire life          1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237630 entries, 0 to 237629
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   tientID                   237630 non-null  int64
#  1   State                      237630 non-null  object
#  2   Sex                        237630 non-null  object
#  3   GeneralHealth              237630 non-null  object
#  4   AgeCategory                237630 non-null  object
#  5   HeightInMeters             237630 non-null  float64
#  6   WeightInKilograms          237630 non-null  float64
#  7   BMI                        237630 non-null  float64
#  8   HadHeartAttack             237630 non-null  int64
#  9   HadAngina                  237630 non-null  int64
#  10  HadStroke                  237630 non-null  int64
#  11  HadAsthma                  237630 non-null  int64
#  12  HadSkinCancer              237630 non-null  int64
# ...

# %%
print(df['GeneralHealth'].unique())
# Out:
# ['Fair' 'Very good' 'Excellent' 'Good' 'Poor']

# %%
df['GeneralHealth'].replace(['Poor', 'Fair', 'Good', 'Very good', 'Excellent'],[1,2,3,4,5],inplace=True)
# Out:
# /tmp/ipykernel_2673/2441845280.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GeneralHealth'].replace(['Poor', 'Fair', 'Good', 'Very good', 'Excellent'],[1,2,3,4,5],inplace=True)
# /tmp/ipykernel_2673/2441845280.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
df
# Out:
#         tientID        State     Sex  GeneralHealth   AgeCategory  \
# 0              1      Alabama  Female              2  Age 75 to 79
# 1              2      Alabama  Female              4  Age 65 to 69
# 2              3      Alabama    Male              5  Age 60 to 64
# 3              4      Alabama    Male              4  Age 70 to 74
# 4              5      Alabama  Female              3  Age 50 to 54
# ...          ...          ...     ...            ...           ...
# 237625    237626  Puerto Rico  Female              3  Age 60 to 64
# 237626    237627  Puerto Rico  Female              3  Age 55 to 59
# 237627    237628  Puerto Rico    Male              2  Age 45 to 49
# 237628    237629  Puerto Rico  Female              4  Age 25 to 29
# 237629    237630  Puerto Rico  Female              3  Age 30 to 34
#
#         HeightInMeters  WeightInKilograms        BMI  HadHeartAttack  \
# 0                 1.63          84.820000  32.099998               0
# ...

# %%
print(df['RaceEthnicityCategory'].unique())
# Out:
# ['White only, Non-Hispanic' 'Black only, Non-Hispanic'
#  'Other race only, Non-Hispanic' 'Multiracial, Non-Hispanic' 'Hispanic']

# %%
df['RaceEthnicityCategory'].replace([
 'White only, Non-Hispanic',
 'Black only, Non-Hispanic',
 'Other race only, Non-Hispanic',
 'Multiracial, Non-Hispanic',
 'Hispanic'
],[1,2,3,4,5],inplace=True)
# Out:
# /tmp/ipykernel_2673/2296525074.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RaceEthnicityCategory'].replace([
# /tmp/ipykernel_2673/2296525074.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['RaceEthnicityCategory'].replace([

# %%
print(df['ECigaretteUsage'].unique())
# Out:
# ['Never used e-cigarettes in my entire life' 'Not at all (right now)'
#  'Use them some days' 'Use them every day']

# %%
df['ECigaretteUsage'].replace([
 'Never used e-cigarettes in my entire life',
 'Not at all (right now)',
 'Use them some days',
 'Use them every day'
],[1,2,3,4],inplace=True)
# Out:
# /tmp/ipykernel_2673/2435030969.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ECigaretteUsage'].replace([
# /tmp/ipykernel_2673/2435030969.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['ECigaretteUsage'].replace([

# %%
print(df['TetanusLast10Tdap'].unique())
# Out:
# ['No, did not receive any tetanus shot in the past 10 years'
#  'Yes, received Tdap' 'Yes, received tetanus shot but not sure what type'
#  'Yes, received tetanus shot, but not Tdap']

# %%
df['TetanusLast10Tdap'].replace([
 'No, did not receive any tetanus shot in the past 10 years',
 'Yes, received Tdap',
 'Yes, received tetanus shot but not sure what type',
 'Yes, received tetanus shot, but not Tdap'
],[1,2,3,4],inplace=True)
# Out:
# /tmp/ipykernel_2673/3338556734.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TetanusLast10Tdap'].replace([
# /tmp/ipykernel_2673/3338556734.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['TetanusLast10Tdap'].replace([

# %%
print(df['AgeCategory'].unique())
# Out:
# ['Age 75 to 79' 'Age 65 to 69' 'Age 60 to 64' 'Age 70 to 74'
#  'Age 50 to 54' 'Age 80 or older' 'Age 55 to 59' 'Age 25 to 29'
#  'Age 40 to 44' 'Age 30 to 34' 'Age 35 to 39' 'Age 18 to 24'
#  'Age 45 to 49']

# %%
df['AgeCategory'].replace([
 'Age 18 to 24',
 'Age 25 to 29',
 'Age 30 to 34',
 'Age 35 to 39',
 'Age 40 to 44',
 'Age 45 to 49',
 'Age 50 to 54',
 'Age 55 to 59',
 'Age 60 to 64',
 'Age 65 to 69',
 'Age 70 to 74',
 'Age 75 to 79',
 'Age 80 or older'
],[21,27,32,37,42,47,52,57,62,67,72,77,82],inplace=True)
# Out:
# /tmp/ipykernel_2673/1555940462.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AgeCategory'].replace([
# /tmp/ipykernel_2673/1555940462.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['AgeCategory'].replace([

# %%
print(df['HadDiabetes'].unique())
# Out:
# ['Yes' 'No' 'No, pre-diabetes or borderline diabetes'
#  'Yes, but only during pregnancy (female)']

# %%
df["HadDiabetes"].replace([
 'No',
 'No, pre-diabetes or borderline diabetes',
 'Yes, but only during pregnancy (female)',
 'Yes'
]
,[1,2,3,4],inplace=True)
# Out:
# /tmp/ipykernel_2673/2480833874.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["HadDiabetes"].replace([
# /tmp/ipykernel_2673/2480833874.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["HadDiabetes"].replace([

# %%
print(df['SmokerStatus'].unique())
# Out:
# ['Former smoker' 'Never smoked' 'Current smoker - now smokes every day'
#  'Current smoker - now smokes some days']

# %%
df['SmokerStatus'].replace([
 'Never smoked',
 'Former smoker',
 'Current smoker - now smokes some days',
 'Current smoker - now smokes every day'
],[1,2,3,4],inplace=True)
# Out:
# /tmp/ipykernel_2673/3192532598.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SmokerStatus'].replace([
# /tmp/ipykernel_2673/3192532598.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['SmokerStatus'].replace([

# %%
df
# Out:
#         tientID        State     Sex  GeneralHealth  AgeCategory  \
# 0              1      Alabama  Female              2           77
# 1              2      Alabama  Female              4           67
# 2              3      Alabama    Male              5           62
# 3              4      Alabama    Male              4           72
# 4              5      Alabama  Female              3           52
# ...          ...          ...     ...            ...          ...
# 237625    237626  Puerto Rico  Female              3           62
# 237626    237627  Puerto Rico  Female              3           57
# 237627    237628  Puerto Rico    Male              2           47
# 237628    237629  Puerto Rico  Female              4           27
# 237629    237630  Puerto Rico  Female              3           32
#
#         HeightInMeters  WeightInKilograms        BMI  HadHeartAttack  \
# 0                 1.63          84.820000  32.099998               0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])
df['RaceEthnicityCategory']=le.fit_transform(df['RaceEthnicityCategory'])
df['TetanusLast10Tdap']=le.fit_transform(df['TetanusLast10Tdap'])
df['AgeCategory']=le.fit_transform(df['AgeCategory'])
df['State']=le.fit_transform(df['State'])
df['HadDiabetes']=le.fit_transform(df['HadDiabetes'])

# %%
df
# Out:
#         tientID  State  Sex  GeneralHealth  AgeCategory  HeightInMeters  \
# 0              1      0    0              2           11            1.63
# 1              2      0    0              4            9            1.60
# 2              3      0    1              5            8            1.78
# 3              4      0    1              4           10            1.78
# 4              5      0    0              3            6            1.68
# ...          ...    ...  ...            ...          ...             ...
# 237625    237626     40    0              3            8            1.57
# 237626    237627     40    0              3            7            1.70
# 237627    237628     40    1              2            5            1.75
# 237628    237629     40    0              4            1            1.57
# 237629    237630     40    0              3            2            1.60
#
#         WeightInKilograms        BMI  HadHeartAttack  HadAngina  ...  \
# ...

# %%
df
# Out:
#         tientID  State  Sex  GeneralHealth  AgeCategory  HeightInMeters  \
# 0              1      0    0              2           11            1.63
# 1              2      0    0              4            9            1.60
# 2              3      0    1              5            8            1.78
# 3              4      0    1              4           10            1.78
# 4              5      0    0              3            6            1.68
# ...          ...    ...  ...            ...          ...             ...
# 237625    237626     40    0              3            8            1.57
# 237626    237627     40    0              3            7            1.70
# 237627    237628     40    1              2            5            1.75
# 237628    237629     40    0              4            1            1.57
# 237629    237630     40    0              3            2            1.60
#
#         WeightInKilograms        BMI  HadHeartAttack  HadAngina  ...  \
# ...

# %%
from imblearn.over_sampling import SMOTE
x=df.drop('HadHeartAttack',axis=1)
y=df['HadHeartAttack']
smote=SMOTE(random_state=42)
x_resampled,y_resampled=smote.fit_resample(x,y)
df=pd.concat([x_resampled,y_resampled],axis=1)

# %%
plt.figure(figsize=(15,10))
corr_matrix=df.corr(numeric_only=True)
sns.heatmap(corr_matrix,annot=True,fmt='0.01f',cmap='coolwarm')
plt.title('correlation matrix')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 2 () missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.drop(['State','BMI'],axis=1,inplace=True)

# %%
plt.figure(figsize=(15,10))
HadHeartAttack_corr=df.corr(numeric_only=True)['HadHeartAttack']
HadHeartAttack_corr = HadHeartAttack_corr.drop('HadHeartAttack')
sns.heatmap(HadHeartAttack_corr.to_frame(), annot=True, fmt='.2f', cmap='coolwarm',
            cbar=True, annot_kws={'size': 10})
plt.title('Correlation between HadHeartAttack and Other Features')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 2 () missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.drop(["tientID","Sex","HeightInMeters","WeightInKilograms","HadAsthma","HadSkinCancer","HadDepressiveDisorder","BlindOrVisionDifficulty","DifficultyConcentrating","DifficultyDressingBathing","DifficultyErrands","ECigaretteUsage","RaceEthnicityCategory","AlcoholDrinkers","HIVTesting","FluVaxLast12","TetanusLast10Tdap","HighRiskLastYear",'CovidPos'],axis=1,inplace=True)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237630 entries, 0 to 237629
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   GeneralHealth        237630 non-null  int64
#  1   AgeCategory          237630 non-null  int64
#  2   HadHeartAttack       237630 non-null  int64
#  3   HadAngina            237630 non-null  int64
#  4   HadStroke            237630 non-null  int64
#  5   HadCOPD              237630 non-null  int64
#  6   HadKidneyDisease     237630 non-null  int64
#  7   HadArthritis         237630 non-null  int64
#  8   HadDiabetes          237630 non-null  int64
#  9   DeafOrHardOfHearing  237630 non-null  int64
#  10  DifficultyWalking    237630 non-null  int64
#  11  SmokerStatus         237630 non-null  int64
#  12  ChestScan            237630 non-null  int64
#  13  PneumoVaxEver        237630 non-null  int64
# dtypes: int64(14)
# memory usage: 25.4 MB

# %%
def remove_outliers_iqr(df,exclude_column):
  for col in df.columns:
    if col==exclude_column:
      continue
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1
    lower_bound=Q1-1.5*IQR
    upper_bound=Q3+1.5*IQR
    df=df[(df[col]>=lower_bound)&(df[col] <=upper_bound)]
  return df
df_cleaned=remove_outliers_iqr(df,exclude_column='HadHeartAttack')
df=df_cleaned

# %%
df.shape
# Out:
# (105370, 14)

# %%
df
# Out:
#         GeneralHealth  AgeCategory  HadHeartAttack  HadAngina  HadStroke  \
# 2                   5            8               0          0          0
# 4                   3            6               0          0          0
# 10                  3            7               0          0          0
# 11                  3            1               0          0          0
# 12                  3            6               0          0          0
# ...               ...          ...             ...        ...        ...
# 237612              5            3               0          0          0
# 237613              3           10               0          0          0
# 237614              3            9               0          0          0
# 237620              2            1               0          0          0
# 237628              4            1               0          0          0
#
#         HadCOPD  HadKidneyDisease  HadArthritis  HadDiabetes  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
features=['GeneralHealth','AgeCategory','HadHeartAttack','HadAngina','HadStroke','HadCOPD','HadKidneyDisease','HadArthritis','HadDiabetes','DeafOrHardOfHearing','DifficultyWalking','SmokerStatus','ChestScan','PneumoVaxEver']
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df[features])
scaled_df=pd.DataFrame(scaled_data,columns=features)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd



X = df[['GeneralHealth','AgeCategory','HadAngina','HadStroke','HadCOPD','HadKidneyDisease','HadArthritis','HadDiabetes','DeafOrHardOfHearing','DifficultyWalking','SmokerStatus','ChestScan','PneumoVaxEver']]
y = df['HadHeartAttack']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)


model=LogisticRegression()
model.fit(X_train, y_train)


y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Baseline model accuracy: {accuracy:.2f}')
# Out:
# Baseline model accuracy: 0.75

# %% [markdown]
# # conclusion
#
#
# In this project, a machine learning model was developed to predict whether a patient has experienced a heart attack based on demographic, lifestyle, and health-related factors. By analyzing these features, the model was able to identify patterns associated with heart attack risk and classify patients accordingly.
#
# The results demonstrate that predictive analytics can be a valuable tool in healthcare for early risk detection and decision-making. Such models can assist healthcare professionals in identifying high-risk individuals, enabling timely intervention and preventive measures.
#
# Although the model provides useful insights, its accuracy depends on the quality and completeness of the data. Future improvements can include larger datasets, additional medical parameters, and advanced machine learning techniques to enhance prediction performance and reliability.
